# %% [markdown]
# Problem 1: User Login Check

# %%
print("----- Task 1: User Login Check -----")

correct_username = "admin"
correct_password = "1234"

# You can change these to input() if required
username = "admin"
password = "1234"

if username == correct_username and password == correct_password:
    print("Login Successful")
else:
    print("Invalid Credentials")
# Out:
# ----- Task 1: User Login Check -----
# Login Successful

# %% [markdown]
# Problem 2: Pass/Fail Analyser

# %%
print("\n----- Task 2: Pass / Fail Analyzer -----")

marks = [45, 78, 90, 33, 60]

pass_count = 0
fail_count = 0

for m in marks:
    if m >= 50:
        pass_count += 1
    else:
        fail_count += 1

print("Total Students:", len(marks))
print("Passed Students:", pass_count)
print("Failed Students:", fail_count)
# Out:
# ----- Task 2: Pass / Fail Analyzer -----
# Total Students: 5
# Passed Students: 3
# Failed Students: 2

# %% [markdown]
# Problem 3: Simple Data Cleaner

# %%
print("\n----- Task 3: Simple Data Cleaner -----")

names = [" Alice ", "bob", " CHARLIE "]

cleaned_names = []

for name in names:
    cleaned = name.strip().lower()
    cleaned_names.append(cleaned)

print("Original Names:", names)
print("Cleaned Names:", cleaned_names)
# Out:
# ----- Task 3: Simple Data Cleaner -----
# Original Names: [' Alice ', 'bob', ' CHARLIE ']
# Cleaned Names: ['alice', 'bob', 'charlie']

# %% [markdown]
# Problem 4: Message Length Analyser

# %%
print("\nTask 4 - Message Length Analyzer")

messages = ["Hi", "Welcome to the platform", "OK"]

for m in messages:
    print("Message:", m)
    print("Length:", len(m))

    if len(m) > 10:
        print("This message is longer than 10 characters")
    print()
# Out:
# Task 4 - Message Length Analyzer
# Message: Hi
# Length: 2
#
# Message: Welcome to the platform
# Length: 23
# This message is longer than 10 characters
#
# Message: OK
# Length: 2

# %% [markdown]
# Problem 5: Errror Message Detector

# %%
print("\nTask 5 - Error Message Detector")

logs = ["INFO", "ERROR", "WARNING", "ERROR"]

error_total = 0

for item in logs:
    if item == "ERROR":
        error_total = error_total + 1

print("Total ERROR messages:", error_total)
# Out:
# Task 5 - Error Message Detector
# Total ERROR messages: 2
